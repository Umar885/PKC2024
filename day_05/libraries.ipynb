# %% [markdown]
# # Libraries Name
# 1. Pandas
# 2. Numpy
# 3. Seaborn
# 4. Matplotlib
# 5. Plotly
# 6. Scipy
# 7. Scikit-learn
# 8. Streamlit

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # All libraries already installed

# %% [markdown]
# # Import the libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from sklearn.metrics import mean_absolute_error

# %%
# plotting
sns.set_theme(style='darkgrid')
diamonds = sns.load_dataset("diamonds")
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.boxplot(x="clarity", y="price", data=diamonds.sort_values(by="clarity", key=lambda x: x.map(dict(zip(clarity_ranking, range(len(clarity_ranking)))))))
# Out:
# c:\Users\Kashif\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:641: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <Axes: xlabel='clarity', ylabel='price'>

# %%
import plotly.express as px
df = px.data.gapminder()

fig = px.scatter(df.query("year==2007"), x="gdpPercap", y="lifeExp",
	         size="pop", color="continent",
                 hover_name="country", log_x=True, size_max=60)
fig.show()

# %% [markdown]
# Website Title: Data Dive 📊
#
# Blog Post Title: Unveiling the Data Science Odyssey: Navigating the Life Cycle of Insights 🚀
#
# Introduction:
# Welcome to Data Dive, where we plunge into the depths of data science to uncover the secrets of insights! 🌊 In this blog post, we'll embark on an exciting journey through the data science life cycle, exploring each step with curiosity and enthusiasm. Join us as we navigate through the twists and turns of this thrilling odyssey! 🌟
#
# Step 1: Data Collection and Preparation 📚
# The journey begins with the collection and preparation of data. 📊 We gather raw data from various sources, ensuring its quality and reliability. Then, we clean and preprocess the data, making it ready for analysis. This step lays the foundation for our exploration into the world of insights.
#
# Step 2: Exploratory Data Analysis (EDA) 🔍
# With our data prepared, we dive into exploratory data analysis (EDA). 📈 Using visualizations and statistical techniques, we uncover patterns, trends, and correlations within the data. EDA provides us with valuable insights and guides our next steps in the journey.
#
# Step 3: Model Development and Evaluation 🧠
# Next, we embark on the development and evaluation of predictive models and algorithms. 🛠️ We train and fine-tune our models using the insights gained from EDA, ensuring their accuracy and effectiveness. Evaluation helps us assess the performance of our models and refine them for optimal results.
#
# Step 4: Deployment and Implementation 🚀
# With our models ready, it's time to deploy them into the real world. 🌎 We implement our data-driven solutions in practical applications, solving real-world problems and making meaningful impacts. Deployment marks the culmination of our journey, as we witness the transformation of insights into action.
#
# Step 5: Continuous Improvement and Optimization 🔧
# But our journey doesn't end here. 🔄 We believe in the power of continuous improvement and optimization. We monitor the performance of our models, gather feedback, and iterate upon them to enhance their effectiveness. This iterative process ensures that our insights remain relevant and valuable over time.
#
# Conclusion:
# As we reach the end of our data science odyssey, we reflect on the exhilarating journey we've undertaken. 🎉 From data collection to deployment, each step has been filled with discovery and excitement. Join us on future expeditions as we continue to explore the vast possibilities of data science. Together, let's unveil the endless potential of insights! ✨
